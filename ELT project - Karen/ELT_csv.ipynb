# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Read CSV file & preview of the DataFrame

file = 'companylist.csv'
df = pd.read_csv(file, encoding="ISO-8859-1")
df.head()
# Out:
#   Symbol                    Name  LastSale MarketCap  IPOyear  \
# 0    DDD  3D Systems Corporation      8.24  $961.53M      NaN
# 1    MMM              3M Company    164.71   $94.75B      NaN
# 2   WBAI         500.com Limited      9.88     $423M   2013.0
# 3   WUBA             58.com Inc.     51.33    $7.63B   2013.0
# 4   EGHT                 8x8 Inc     23.32    $2.32B      NaN
#
#               Sector                                         industry  \
# 0         Technology          Computer Software: Prepackaged Software
# 1        Health Care                       Medical/Dental Instruments
# 2  Consumer Services            Services-Misc. Amusement & Recreation
# 3         Technology  Computer Software: Programming, Data Processing
# 4         Technology                                     EDP Services
#
#                         Summary Quote  Unnamed: 8
# 0   https://www.nasdaq.com/symbol/ddd         NaN
# 1   https://www.nasdaq.com/symbol/mmm         NaN
# ...

# %%
# Delete extraneous columns and NA values in Sectors & Industry
df2 = df.drop(['IPOyear','MarketCap','Summary Quote','Unnamed: 8'], axis=1)
df2.dropna(subset=['LastSale', 'Sector'])
# df2.head()
# Out:
#      Symbol                                 Name  LastSale  \
# 0       DDD               3D Systems Corporation    8.2400
# 1       MMM                           3M Company  164.7100
# 2      WBAI                      500.com Limited    9.8800
# 3      WUBA                          58.com Inc.   51.3300
# 4      EGHT                              8x8 Inc   23.3200
# 5       AHC                A.H. Belo Corporation    3.4500
# 6       AOS                A.O Smith Corporation   43.6500
# 7      ATEN                   A10 Networks, Inc.    7.0900
# 8       AAC                   AAC Holdings, Inc.    0.7500
# 9       AIR                            AAR Corp.   39.4600
# 10      AAN                   Aaron&#39;s,  Inc.   61.5600
# 11      ABB                              ABB Ltd   18.0500
# 12      ABT                  Abbott Laboratories   83.1600
# 13     ABBV                          AbbVie Inc.   65.2300
# 14      ANF          Abercrombie & Fitch Company   16.8100
# ...
