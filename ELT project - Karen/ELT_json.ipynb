# %%
# Dependencies
import json
import os
import requests
import pandas as pd

# %%
url ="https://financialmodelingprep.com/api/stock/list/all?datatype=json"

# %%
stock_response = requests.get(url)

# %%
# Save post's JSON
stock_json = stock_response.json()
stock_json
# Out:
# [{'Ticker': 'SPY',
#   'Price': 287.89,
#   'companyName': 'SPDR S&P 500',
#   'image': 'https://financialmodelingprep.com/images-New-jpg/.jpg'},
#  {'Ticker': 'CMCSA',
#   'Price': 42.1,
#   'companyName': 'Comcast Corporation Class A Common Stock',
#   'image': 'https://financialmodelingprep.com/images-New-jpg/.jpg'},
#  {'Ticker': 'KMI',
#   'Price': 20.03,
#   'companyName': 'Kinder Morgan Inc.',
#   'image': 'https://financialmodelingprep.com/images-New-jpg/.jpg'},
#  {'Ticker': 'INTC',
#   'Price': 47.02,
#   'companyName': 'Intel Corporation',
#   'image': 'https://financialmodelingprep.com/images-New-jpg/.jpg'},
#  {'Ticker': 'MU',
#   'Price': 42.67,
#   'companyName': 'Micron Technology Inc.',
#   'image': 'https://financialmodelingprep.com/images-New-jpg/.jpg'},
#  {'Ticker': 'GDX',
#   'Price': 28.6,
#   'companyName': 'VanEck Vectors Gold Miners',
#   'image': 'https://financialmodelingprep.com/images-New-jpg/.jpg'},
#  {'Ticker': 'GE',
#   'Price': 9.55,
# ...

# %%
data = pd.DataFrame(stock_json)
stock_data=data.drop(["image"],axis=1)
stock_data.head()
# Out:
#     Price Ticker                               companyName
# 0  287.89    SPY                              SPDR S&P 500
# 1   42.10  CMCSA  Comcast Corporation Class A Common Stock
# 2   20.03    KMI                        Kinder Morgan Inc.
# 3   47.02   INTC                         Intel Corporation
# 4   42.67     MU                    Micron Technology Inc.
